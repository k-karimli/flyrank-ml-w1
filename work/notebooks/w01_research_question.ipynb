# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/k-karimli/FlyRankWeek1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ## My lane
#
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# I chose this lane because it focuses on identifying which content pages should be reviewed first. Instead of reviewing every page manually, the goal is to prioritize pages using observable search and engagement signals. This makes the review process more efficient and provides practical decision support for content teams.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ## Research question
#
# My research question is:
#
# **Which content pages should be reviewed first for refresh based on observable search and engagement signals?**
#
# The decision is which pages deserve review before others.
#
# The action is for a content reviewer or SEO specialist to inspect and update the highest-ranked pages.
#
# A wrong recommendation may cause the team to spend time reviewing low-value pages while missing pages with higher improvement potential. This project provides decision support rather than guaranteeing that a refresh will improve performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# ## Quick look at the data
#
# The starter dataset contains observable search and engagement signals for individual content pages.
#
# For example:
#
# - The dataset contains **[rows]** content pages.
# - The average 90-day impressions are **[value]**.
# - The average 90-day sessions are **[value]**.
#
# These observations suggest that the dataset contains enough information to prioritize content review opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/k-karimli/FlyRankWeek1.git
# %cd FlyRankWeek1
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")  # yolu öz mühitinə uyğunlaşdır

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df["trend_direction"].value_counts())

df.head()

print("Average impressions:", df["impressions_90d"].mean())
print("Average sessions:", df["sessions_90d"].mean())
print("Average CTR:", df["ctr"].mean())
# Out:
# Cloning into 'FlyRankWeek1'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 132 (delta 45), reused 95 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (132/132), 1.85 MiB | 14.24 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/FlyRankWeek1
# Rows: 30000
# Columns: 44
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Average impressions: 5200.3663
# Average sessions: 37.066633333333336
# Average CTR: 0.5107333333333334

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ## Careful wording
#
# This project can identify observed patterns and rank pages using measurable search and engagement signals. The results are intended to support content review decisions.
#
# This project cannot prove that refreshing a page will cause better rankings or more traffic. It also cannot predict Google's algorithms or guarantee future performance. Any recommendations should be reviewed by humans before action is taken.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
