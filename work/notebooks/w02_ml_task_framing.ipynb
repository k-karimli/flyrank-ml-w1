# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/k-karimli/FlyRankWeek1/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
#
#
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# This is a **classification** task. The model predicts whether a content page is likely to be a review candidate (declining) based on observable search and engagement signals.
#
# The output supports ranking pages so reviewers can prioritize which content should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## My lane as an ML task

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# The target is **is_declining_label**.
#
# It is a proxy label created from the observable field **trend_direction**.
#
# A page is labeled positive when:
#
# trend_direction == "down"
#
# This is an observed rule-based proxy rather than a future outcome, making it suitable for the starter dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Target or proxy

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# The primary success metric is **Precision@50**.
#
# This metric measures how many of the top 50 recommended pages are actually positive review candidates.
#
# Since reviewers only have time to inspect a limited number of pages, Precision@50 reflects the real business decision better than overall accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Success metric

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row represents **one content page**.
#
# Each row contains observable search, engagement, freshness, and content signals for a single content item.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/k-karimli/flyrank-ml-w1.git
# %cd flyrank-ml-w1
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.shape)

df.head()
print(df.columns.tolist())
df[[
    "content_id",
    "client_id",
    "impressions_90d",
    "sessions_90d",
    "trend_direction"
]].head()
# Out:
# Cloning into 'flyrank-ml-w1'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 127 (delta 41), reused 97 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (127/127), 1.85 MiB | 4.83 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# /content/flyrank-ml-w1
# (30000, 44)
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule cannot capture the complex relationships between visibility, engagement, freshness, content quality, CTR, and search performance.
#
# Machine learning can learn patterns from many interacting features simultaneously and rank review opportunities more accurately than simple if-statements.
#
# The model provides decision support rather than replacing human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Why ML beats a fixed rule

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
